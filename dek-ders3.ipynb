# %%
library(gdata)
# Out:
# gdata: read.xls support for 'XLS' (Excel 97-2004) files ENABLED.
#
# gdata: read.xls support for 'XLSX' (Excel 2007+) files ENABLED.
#
# Attaching package: 'gdata'
#
# The following object is masked from 'package:stats':
#
#     nobs
#
# The following object is masked from 'package:utils':
#
#     object.size
#
# The following object is masked from 'package:base':
#
#     startsWith

# %%
veri<-read.xls("1ekim1aralik-elektrik.xls")

# %%
head(veri,3)
# Out:
#   Tarih      Saat  toplam   dg       hidro_b Linyit  Akarsu komur_ithal ruzgar
# 1 01.10.2017 00:00 28456.08 11420.64 1829.71 4659.49 516.22 6012.35     2387.35
# 2 01.10.2017 01:00 27134.42 11446.65 1181.61 4535.74 427.43 5387.25     2288.62
# 3 01.10.2017 02:00 26052.72 10789.71  989.13 4495.34 588.87 5352.49     2132.50
#   fueloil jeo    asfaltit komur_yerli bio    ptf    smf
# 1 164.5   700.19 340.02   185.5       227.11 147.99 147.99
# 2 163.8   703.56 335.61   191.5       225.65 138.00 121.00
# 3 164.7   703.45 253.91   186.5       227.12 120.65 136.00

# %%
ncol(veri)
# Out:
# [1] 16

# %%
summary(veri)
# Out:
#         Tarih           Saat          toplam               dg
#  01.10.2017:  24   00:00  :  62   Min.   :   57.99   Min.   :   45.51
#  01.11.2017:  24   01:00  :  62   1st Qu.:28208.04   1st Qu.:12481.35
#  01.12.2017:  24   02:00  :  62   Median :32860.26   Median :15020.73
#  02.10.2017:  24   03:00  :  62   Mean   :31866.11   Mean   :14541.50
#  02.11.2017:  24   04:00  :  62   3rd Qu.:35148.50   3rd Qu.:16929.09
#  03.10.2017:  24   05:00  :  62   Max.   :40746.45   Max.   :19163.33
#  (Other)   :1344   (Other):1116
#     hidro_b            Linyit         Akarsu         komur_ithal
#  Min.   :   1.75   Min.   :   0   Min.   :   7.13   Min.   :   0
#  1st Qu.: 903.17   1st Qu.:4479   1st Qu.: 752.96   1st Qu.:5947
#  Median :1990.01   Median :4678   Median : 956.02   Median :6344
#  Mean   :2143.07   Mean   :4657   Mean   : 965.67   Mean   :6390
#  3rd Qu.:3171.44   3rd Qu.:4852   3rd Qu.:1165.31   3rd Qu.:7001
#  Max.   :6323.42   Max.   :5663   Max.   :2042.30   Max.   :7777
# ...

# %%
head(subset(veri,veri$Saat=="00:00"))
# Out:
#     Tarih      Saat  toplam   dg       hidro_b Linyit  Akarsu  komur_ithal
# 1   01.10.2017 00:00 28456.08 11420.64 1829.71 4659.49  516.22 6012.35
# 25  02.10.2017 00:00 26698.13  9693.27 1463.75 4765.08  637.13 5441.03
# 49  03.10.2017 00:00 29227.27 11285.15 1976.06 4346.91 1451.67 5308.90
# 73  04.10.2017 00:00 29109.43 11319.41 1870.08 4655.33 1236.42 5944.00
# 97  05.10.2017 00:00 29311.02 12618.62 1500.07 4740.20  909.22 6198.37
# 121 06.10.2017 00:00 29586.28 13618.32 2169.01 4569.38  704.44 6248.90
#     ruzgar  fueloil jeo    asfaltit komur_yerli bio    ptf    smf
# 1   2387.35 164.5   700.19 340.02   185.5       227.11 147.99 147.99
# 25  3007.95 162.7   711.88 337.82   184.5       234.43 148.00 114.92
# 49  3084.23 143.2   711.10 335.61   336.5       225.94 126.65  90.65
# 73  2135.19 165.1   717.03 337.82   333.5       236.55 130.00 138.00
# 97  1881.82 132.5   725.26 337.82   358.0       242.14 147.49 121.00
# ...

# %%
saat0<-subset(veri,veri$Saat=="00:00")

# %%
cor(saat0[,3:16])
# Out:
#             toplam      dg          hidro_b     Linyit      Akarsu
# toplam       1.00000000  0.68808202  0.01467561  0.34108327  0.22510287
# dg           0.68808202  1.00000000 -0.31095191  0.04858818  0.05197990
# hidro_b      0.01467561 -0.31095191  1.00000000  0.13497943 -0.17335826
# Linyit       0.34108327  0.04858818  0.13497943  1.00000000 -0.03550940
# Akarsu       0.22510287  0.05197990 -0.17335826 -0.03550940  1.00000000
# komur_ithal  0.64337565  0.51690280 -0.19685386  0.14319206  0.11862609
# ruzgar      -0.20004482 -0.75251685  0.16057565 -0.00349215  0.05193900
# fueloil     -0.31730006 -0.04060689 -0.27877146 -0.33484501  0.07585284
# jeo          0.51733701  0.46114461 -0.16193956  0.29989201 -0.03544656
# asfaltit    -0.30682409 -0.22049628  0.04746026 -0.03413366  0.26937987
# komur_yerli -0.20190379 -0.02166666  0.24201441 -0.13987839 -0.01783656
# bio          0.10490490  0.18499955 -0.07829894  0.27419992  0.03984956
# ...

# %%
saat0<-subset(veri,veri$Saat=="14:00")

# %%
cor(saat0[,3:16])
# Out:
#             toplam      dg          hidro_b     Linyit      Akarsu
# toplam       1.00000000  0.83835178  0.63918587  0.22161634  0.685515455
# dg           0.83835178  1.00000000  0.42406471  0.09113129  0.443353922
# hidro_b      0.63918587  0.42406471  1.00000000 -0.03705247  0.542707046
# Linyit       0.22161634  0.09113129 -0.03705247  1.00000000  0.095173293
# Akarsu       0.68551545  0.44335392  0.54270705  0.09517329  1.000000000
# komur_ithal  0.50775913  0.42238342  0.09954104  0.25530865  0.226564402
# ruzgar      -0.09670356 -0.44662806 -0.28255255 -0.01828640  0.055456268
# fueloil     -0.20968004 -0.07083734 -0.07431002 -0.18487573 -0.066761647
# jeo          0.22419798  0.14902440 -0.04233854  0.16055944 -0.063806593
# asfaltit    -0.15282321 -0.15287801  0.09600743 -0.21753711  0.104424415
# komur_yerli -0.10560507 -0.09146736  0.06475255 -0.01665525 -0.077129966
# bio          0.05163950  0.16496597 -0.06488491 -0.20716806 -0.001699227
# ...
